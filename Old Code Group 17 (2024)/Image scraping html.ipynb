# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

def download_images(url, folder_name):
    if not os.path.isdir(folder_name):
        os.makedirs(folder_name)

    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers)
    html = response.content
    soup = BeautifulSoup(html, 'html.parser')
    img_tags = soup.find_all('img')

    for i, img in enumerate(img_tags):
        try:
            img_url = img.get('src')
            img_url = urljoin(url, img_url)
            basename = os.path.basename(img_url)

            # Skip downloading if basename does not contain 'thumb' or 'fig'
            if 'thumb' not in basename and 'fig' not in basename:
                print(f'Skipped: {basename}')
                continue

            # Add a unique identifier (i) to the filename to prevent overwriting
            img_path = os.path.join(folder_name, f"_{basename}")

            with open(img_path, 'wb') as f:
                img_data = requests.get(img_url, headers=headers).content
                f.write(img_data)
                print(f'Downloaded {img_path}')
        except Exception as e:
            print(f"Could not download {img_url}. Reason: {e}")

url = 'https://atlas.web.cern.ch/Atlas/GROUPS/PHYSICS/PAPERS/EXOT-2014-17/'
folder_name = 'ATLAS_IMAGES'
download_images(url, folder_name)
# Out:
# Skipped: spacer.gif
# Skipped: web-bg.gif
# Skipped: menu-down.gif
# Skipped: lock.gif
# Skipped: web-bg.gif
# Skipped: menu-down.gif
# Skipped: web-bg.gif
# Skipped: menu-down.gif
# Skipped: spacer.gif
# Skipped: spacer.gif
# Skipped: AtlasDetector.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_01a.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_01b.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_01c.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_01d.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_01e.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_01f.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_01g.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_01h.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_01i.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_01j.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_01k.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_01l.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_02a.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_02b.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_02c.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_02d.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_02e.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_02f.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_02g.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_02h.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_02i.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_03a.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_03b.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_03c.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_04a.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_04b.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_04c.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_04d.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_04e.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_05a.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_05b.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_05c.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_05d.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_06a.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_06b.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_07a.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_07b.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_08.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_09.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_10a.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_10b.png
# Downloaded ATLAS_IMAGES/_.thumb_fig_11.png
# Downloaded ATLAS_IMAGES/_.thumb_tab_01.png
# Downloaded ATLAS_IMAGES/_.thumb_tab_02.png
# Downloaded ATLAS_IMAGES/_.thumb_tab_03.png
# Downloaded ATLAS_IMAGES/_.thumb_tab_04.png
# Downloaded ATLAS_IMAGES/_.thumb_tab_05.png
# Downloaded ATLAS_IMAGES/_.thumb_figaux_01.png
# Downloaded ATLAS_IMAGES/_.thumb_figaux_02a.png
# Downloaded ATLAS_IMAGES/_.thumb_figaux_02b.png
# Downloaded ATLAS_IMAGES/_.thumb_figaux_03a.png
# Downloaded ATLAS_IMAGES/_.thumb_figaux_03b.png
# Downloaded ATLAS_IMAGES/_.thumb_figaux_04.png
# Downloaded ATLAS_IMAGES/_.thumb_tabaux_01.png
# Downloaded ATLAS_IMAGES/_.thumb_tabaux_02.png
# Skipped: ATLAS-logo.jpg
